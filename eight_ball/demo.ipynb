# %%
from ball import Ball
from simulation import Simulation

ball1 = Ball()
ball2 = Ball(pos=(1.0, 1.0))
sim = Simulation([ball1, ball2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 ball1 = Ball()
#       5 ball2 = Ball(pos=(1.0, 1.0))
# ----> 6 sim = Simulation([ball1, ball2])
#
# File ~/Documents/eight-ball/eight_ball/simulation.py:21, in Simulation.__init__(self, balls, *args)
#      10 ax.tick_params(
#      11     axis='both',
#      12     which='both',
#    (...)
#      18     labelleft=False
#      19 )
#      20 ax.add_artist(plt.Circle((0., 0.), 9, fill=False))
# ---> 21 self.balls = balls
#      22 for ball in self.balls:
#      23     print(ball.pos)
#
# AttributeError: attribute 'balls' of 'builtins._Simulation' objects is not writable
