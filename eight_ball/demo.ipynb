# %%
# %matplotlib widget
from ball import Ball
from lab import Lab
ball1 = Ball(pos=(.2, .2), vel=(1., 1.2), r=0.05)
ball2 = Ball(pos=(.5, .5), vel=(-0.2, -0.2), r=0.05)
v2_ball1, v2_ball2 = ball1.v_squared(), ball2.v_squared()
v2_sum = v2_ball1 + v2_ball2
print(f"{v2_ball1=:.4f}, {v2_ball2=:.4f}, {v2_sum=}")
lab = Lab(balls=[ball1, ball2])
lab.run()
# Out:
# v2_ball1=2.4400, v2_ball2=0.0800, v2_sum=2.52
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
v2_ball1, v2_ball2 = ball1.v_squared(), ball2.v_squared()
v2_sum = v2_ball1 + v2_ball2
print(f"{v2_ball1=:.4f}, {v2_ball2=:.4f}, {v2_sum=}")
